# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# establish connection
engine = create_engine("sqlite:///Facilities.sqlite")
conn = engine.connect()

# %%
# reflect an existing database into a new model
Base = automap_base()
Base.prepare(engine, reflect=True)

# reflect the tables
Base.metadata.tables
# Out:
# immutabledict({'2019_ed': Table('2019_ed', MetaData(bind=None), Column('year', INTEGER(), table=<2019_ed>), Column('oshpd_id2', INTEGER(), table=<2019_ed>, primary_key=True, nullable=False), Column('oshpd_id', INTEGER(), table=<2019_ed>), Column('FACILITY_NAME', TEXT(), table=<2019_ed>), Column('LICENSE_CATEGORY_DESC', TEXT(), table=<2019_ed>), Column('COUNTY_NAME', TEXT(), table=<2019_ed>), Column('DBA_ADDRESS1', TEXT(), table=<2019_ed>), Column('DBA_CITY', TEXT(), table=<2019_ed>), Column('DBA_ZIP_CODE', INTEGER(), table=<2019_ed>), Column('CONTROL_TYPE_DESC', TEXT(), table=<2019_ed>), Column('TRAUMA_CENTER_DESC', TEXT(), table=<2019_ed>), Column('ER_SERVICE_LEVEL_DESC', TEXT(), table=<2019_ed>), Column('RURAL_HOSPITAL_DESC', TEXT(), table=<2019_ed>), Column('TEACHING_HOSPITAL_DESC', TEXT(), table=<2019_ed>), Column('LICENSED_BED_SIZE', TEXT(), table=<2019_ed>), Column('SENATE_DISTRICT_DESC', TEXT(), table=<2019_ed>), Column('ASSEMBLY_DISTRICT_DESC', TEXT(), table=<2019_ed>), Column('MSSA_NAME', TEXT(), table=<2019_ed>), Column('MSSA_DESIGNATION', TEXT(), table=<2019_ed>), Column('Sex_Female', TEXT(), table=<2019_ed>), Column('Sex_Male', TEXT(), table=<2019_ed>), Column('Sex_Unk', TEXT(), table=<2019_ed>), Column('Age_01_09', TEXT(), table=<2019_ed>), Column('Age_10_19', TEXT(), table=<2019_ed>), Column('Age_20_29', TEXT(), table=<2019_ed>), Column('Age_30_39', TEXT(), table=<2019_ed>), Column('Age_40_49', TEXT(), table=<2019_ed>), Column('Age_50_59', TEXT(), table=<2019_ed>), Column('Age_60_69', TEXT(), table=<2019_ed>), Column('Age_70_79', TEXT(), table=<2019_ed>), Column('Age_80_', TEXT(), table=<2019_ed>), Column('Age_Under_1', TEXT(), table=<2019_ed>), Column('Age_Unknown', TEXT(), table=<2019_ed>), Column('racegrp_aman', TEXT(), table=<2019_ed>), Column('racegrp_asian', TEXT(), table=<2019_ed>), Column('racegrp_black', TEXT(), table=<2019_ed>), Column('racegrp_inv_blank', TEXT(), table=<2019_ed>), Column('racegrp_multirace', TEXT(), table=<2019_ed>), Column('racegrp_nhpi', TEXT(), table=<2019_ed>), Column('racegrp_other', TEXT(), table=<2019_ed>), Column('racegrp_unknown', TEXT(), table=<2019_ed>), Column('racegrp_white', TEXT(), table=<2019_ed>), Column('eth_Hispanic', TEXT(), table=<2019_ed>), Column('eth_NonHispanic', TEXT(), table=<2019_ed>), Column('eth_Unknown', TEXT(), table=<2019_ed>), Column('eth_Blank_Invalid', TEXT(), table=<2019_ed>), Column('disp_Acute_Care', TEXT(), table=<2019_ed>), Column('disp_Against_Medical_Advice', TEXT(), table=<2019_ed>), Column('disp_Died', TEXT(), table=<2019_ed>), Column('disp_Hospice_Care', TEXT(), table=<2019_ed>), Column('disp_Invalid_Blank', TEXT(), table=<2019_ed>), Column('disp_Not_Defined_Elsewhere', TEXT(), table=<2019_ed>), Column('disp_Prison_Jail', TEXT(), table=<2019_ed>), Column('disp_Psychiatric_Care', TEXT(), table=<2019_ed>), Column('disp_Routine', TEXT(), table=<2019_ed>), Column('disp_SN_IC_Care', TEXT(), table=<2019_ed>), Column('disp_CAH', TEXT(), table=<2019_ed>), Column('disp_Childrens_or_Cancer', TEXT(), table=<2019_ed>), Column('disp_Home_Health_Service', TEXT(), table=<2019_ed>), Column('disp_Rehab', TEXT(), table=<2019_ed>), Column('disp_Residential_Care', TEXT(), table=<2019_ed>), Column('disp_Other', TEXT(), table=<2019_ed>), Column('disp_Disaster_Care_Site', TEXT(), table=<2019_ed>), Column('Medi_Cal', TEXT(), table=<2019_ed>), Column('Medicare', TEXT(), table=<2019_ed>), Column('Other_Payer', TEXT(), table=<2019_ed>), Column('Private_Coverage', TEXT(), table=<2019_ed>), Column('SelfPay', TEXT(), table=<2019_ed>), Column('Unknown_inv_Payer', TEXT(), table=<2019_ed>), Column('DX_Blood_Forming', TEXT(), table=<2019_ed>), Column('DX_Circulatory', TEXT(), table=<2019_ed>), Column('DX_Congenital', TEXT(), table=<2019_ed>), Column('DX_Digestive', TEXT(), table=<2019_ed>), Column('DX_Endocrine', TEXT(), table=<2019_ed>), Column('DX_Genitourinary', TEXT(), table=<2019_ed>), Column('DX_Infections', TEXT(), table=<2019_ed>), Column('DX_Injury_Poisoning', TEXT ...

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['2019_ed',
#  '2019_edwithTarget',
#  'AccessToCare',
#  'All_Facilities',
#  'Food_Pantry',
#  'Health_Profiles',
#  'LA_ed_data',
#  'LosAnglesCountyLicData',
#  'hos_encounters',
#  'hosp19_util_data_prelim',
#  'hosp19_util_data_prelimOld',
#  'hospMergedwithTarget',
#  'hospMergedwithTargetOld',
#  'hospitals',
#  'three_year_compare',
#  'three_year_comparewithTarget']

# %%
# Save references to each table
Licensed  = Base.classes.LosAnglesCountyLicData
